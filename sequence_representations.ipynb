# %% [markdown]
# # Imports and set up

# %%
import numpy as np
import pandas as pd

from blomap import blomap_extra_encode, add_padding

# %% [markdown]
# # Get the data

# %%
DATA_PATH = '/home/dreamtim/Coding/itmo-cpp/with_processed_sequences.csv'
# This file can be downloaded from the kaggle notebook

# %%
df = pd.read_csv(DATA_PATH, index_col=0)
df.head()
# Out:
#                                            sequence extra_name cpp_category  \
# 0                   (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK        NaN          NaN
# 3                       (Acp)-RKRRQTSMTDFYHSKRRLIFS        NaN          NaN
# 7  (biotin)-lclrpvgggweaklakalakalakhlakalakalkacea        NaN          NaN
# 8           (biotin)-lclrpvggrsqsrsryyrqrqrsrrrrrrs        NaN          NaN
# 9                                   ?A-RR-[KRRRRRE]        NaN          NaN
#
#    seq_length  is_cpp cpp_type origin  mol_weight           sequence_category  \
# 0         NaN    True      NaN    NaN         NaN  Peptide with Substitutions
# 3         NaN    True      NaN    NaN         NaN  Peptide with Substitutions
# 7         NaN    True      NaN    NaN         NaN                Biotinylated
# 8         NaN    True      NaN    NaN         NaN                Biotinylated
# 9         NaN    True      NaN    NaN         NaN                     Unknown
#
#             standard_sequence  nh3_tail  po3_pos  biotinylated  \
# 0  AKKKKKRFSFKKSFKLSGFSFKKNKK     False    False         False
# 3      ARKRRQTSMTDFYHSKRRLIFS     False    False         False
# 7                         NaN     False    False          True
# 8                         NaN     False    False          True
# 9                  ARRKRRRRRE     False    False         False
#
#    acylated_n_terminal  cyclic  amidated  stearyl_uptake  \
# 0                False   False     False           False
# 3                False   False     False           False
# 7                False   False     False           False
# 8                False   False     False           False
# 9                False   False     False           False
#
#    hexahistidine_tagged         modifications
# 0                 False  [('C', 2), ('P', 3)]
# 3                 False  [('C', 2), ('P', 3)]
# 7                 False                    []
# 8                 False                    []
# 9                 False                    []

# %%
df['seq_length'] = df['sequence'].apply(lambda s: len(s) if isinstance(s, str) else 0)

# %% [markdown]
# # Embeddings

# %% [markdown]
# ### Blomap

# %%
SEQ_LEN = df['seq_length'].max()
print(SEQ_LEN)
# Out:
# 269

# %%
df['adjusted_sequence'] = df['standard_sequence'].apply(lambda s: add_padding(s, SEQ_LEN) if isinstance(s, str) else s)

# %%
df.head()
# Out:
#                                            sequence extra_name cpp_category  \
# 0                   (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK        NaN          NaN
# 3                       (Acp)-RKRRQTSMTDFYHSKRRLIFS        NaN          NaN
# 7  (biotin)-lclrpvgggweaklakalakalakhlakalakalkacea        NaN          NaN
# 8           (biotin)-lclrpvggrsqsrsryyrqrqrsrrrrrrs        NaN          NaN
# 9                                   ?A-RR-[KRRRRRE]        NaN          NaN
#
#    seq_length  is_cpp cpp_type origin  mol_weight           sequence_category  \
# 0          31    True      NaN    NaN         NaN  Peptide with Substitutions
# 3          27    True      NaN    NaN         NaN  Peptide with Substitutions
# 7          48    True      NaN    NaN         NaN                Biotinylated
# 8          39    True      NaN    NaN         NaN                Biotinylated
# 9          15    True      NaN    NaN         NaN                     Unknown
#
#             standard_sequence  nh3_tail  po3_pos  biotinylated  \
# 0  AKKKKKRFSFKKSFKLSGFSFKKNKK     False    False         False
# 3      ARKRRQTSMTDFYHSKRRLIFS     False    False         False
# 7                         NaN     False    False          True
# 8                         NaN     False    False          True
# 9                  ARRKRRRRRE     False    False         False
#
#    acylated_n_terminal  cyclic  amidated  stearyl_uptake  \
# 0                False   False     False           False
# 3                False   False     False           False
# 7                False   False     False           False
# 8                False   False     False           False
# 9                False   False     False           False
#
#    hexahistidine_tagged         modifications  \
# 0                 False  [('C', 2), ('P', 3)]
# 3                 False  [('C', 2), ('P', 3)]
# 7                 False                    []
# 8                 False                    []
# 9                 False                    []
#
#                                    adjusted_sequence
# 0  AKKKKKRFSFKKSFKLSGFSFKKNKKXXXXXXXXXXXXXXXXXXXX...
# 3  ARKRRQTSMTDFYHSKRRLIFSXXXXXXXXXXXXXXXXXXXXXXXX...
# 7                                                NaN
# 8                                                NaN
# 9  ARRKRRRRREXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX...

# %%
# Get a non-NaN sequence
non_nan_sequence = df['adjusted_sequence'].dropna().iloc[0]

# Get the Blomap embedding for the sequence
embedding = blomap_extra_encode(non_nan_sequence)

# Get the length of the embedding
SHAPE = len(embedding)
print(SHAPE)
# Out:
# 2959

# %%
blomap_embeddings = list(df['adjusted_sequence'].apply(blomap_extra_encode, args=(SHAPE,)))
# Out:
# /home/dreamtim/Coding/itmo-cpp/blomap.py:42: Warning: non-standard amino acid in seqeunce
#   warnings.warn("non-standard amino acid in seqeunce", Warning)

# %%
blomap_embeddings = np.array(blomap_embeddings)
print(blomap_embeddings.shape)
# Out:
# (3103, 2959)

# %%
np.save('blomap_embeddings.npy', blomap_embeddings)

# %% [markdown]
# ### ProtBERT

# %%
# %%capture
# %pip install transformers torch

# %%
import torch
from transformers import BertModel, BertTokenizer

# %%
# Load the pre-trained ProtBERT model and tokenizer
model_name = "Rostlab/prot_bert_bfd"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# %%
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.cuda.current_device())  # Should return the current GPU device ID
print(torch.cuda.get_device_name(torch.cuda.current_device()))  # GPU name
# Out:
# True
# 0
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30, 1024, padding_idx=0)
#     (position_embeddings): Embedding(40000, 1024)
#     (token_type_embeddings): Embedding(2, 1024)
#     (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-29): 30 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=1024, out_features=1024, bias=True)
#             (key): Linear(in_features=1024, out_features=1024, bias=True)
#             (value): Linear(in_features=1024, out_features=1024, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=4096, out_features=1024, bias=True)
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def get_protbert_embedding(sequence):
    # Tokenize the sequence
    inputs = tokenizer(sequence, return_tensors="pt", padding=True, truncation=True, max_length=1024)

    # Move inputs to GPU
    inputs = {key: value.to(device) for key, value in inputs.items()}

    # Get embeddings from the model
    with torch.no_grad():
        outputs = model(**inputs)

    # Get the embeddings (the last hidden states of the model)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze()  # Average the token embeddings across the sequence
    return embeddings

# %%
example_sequence = df['standard_sequence'].dropna().iloc[0]
embedding = get_protbert_embedding(example_sequence)
print(embedding.shape)
# Out:
# torch.Size([1024])

# %%
# Get ProtBERT embeddings for all sequences in parallel on GPU
sequences = df['standard_sequence'].fillna('').tolist()  # Fill NaN with empty strings
batch_size = 32  # Adjust batch size based on your GPU memory

protbert_embeddings = []

for i in range(0, len(sequences), batch_size):
    batch_sequences = sequences[i:i + batch_size]
    inputs = tokenizer(batch_sequences, return_tensors="pt", padding=True, truncation=True, max_length=1024)
    inputs = {key: value.to(device) for key, value in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()  # Move to CPU

    protbert_embeddings.append(batch_embeddings)

protbert_embeddings = np.vstack(protbert_embeddings)
print(protbert_embeddings.shape)

# Save the embeddings to a .npy file
np.save('protbert_embeddings.npy', protbert_embeddings)
# Out:
# (3103, 1024)

# %% [markdown]
# ### AlphaFold
#
# See openfold dir!

# %% [markdown]
# # SMILES

# %%
df.columns
# Out:
# Index(['sequence', 'extra_name', 'cpp_category', 'seq_length', 'is_cpp',
#        'cpp_type', 'origin', 'mol_weight', 'sequence_category',
#        'standard_sequence', 'nh3_tail', 'po3_pos', 'biotinylated',
#        'acylated_n_terminal', 'cyclic', 'amidated', 'stearyl_uptake',
#        'hexahistidine_tagged', 'modifications'],
#       dtype='object')

# %%
import re
from rdkit import Chem

# %%
# SMILES map for common modifications
modification_smiles_map = {
    "Ac-": "CC(=O)",                # Acetyl group (N-terminal acetylation)
    "(biotin)": "C1CCCCC1NC(=O)CCC(=O)N",  # Biotin
    "-NH2": "N",                    # Amidation (C-terminal -NH2)
    "Stearyl": "CCCCCCCCCCCCCCCC(=O)",  # Stearyl group
    "Myristoyl": "CCCCCCCCCCCCCC(=O)",  # Myristoyl group
    "Lauroyl": "CCCCCCCCCCCC(=O)"       # Lauroyl group
}

# %%
aa_smiles_map = {
    'A': 'N[C@@H](C)C(=O)',  'a': 'N[C@H](C)C(=O)',  # Alanine
    'C': 'N[C@@H](CS)C(=O)', 'c': 'N[C@H](CS)C(=O)',  # Cysteine
    'D': 'N[C@@H](CC(=O)O)C(=O)', 'd': 'N[C@H](CC(=O)O)C(=O)',  # Aspartic acid
    'E': 'N[C@@H](CCC(=O)O)C(=O)', 'e': 'N[C@H](CCC(=O)O)C(=O)',  # Glutamic acid
    'F': 'N[C@@H](CC1=CC=CC=C1)C(=O)', 'f': 'N[C@H](CC1=CC=CC=C1)C(=O)',  # Phenylalanine
    'G': 'NCC(=O)', 'g': 'NCC(=O)',  # Glycine
    'H': 'N[C@@H](CC1=CNC=N1)C(=O)', 'h': 'N[C@H](CC1=CNC=N1)C(=O)',  # Histidine
    'I': 'N[C@@H](C(C)CC)C(=O)', 'i': 'N[C@H](C(C)CC)C(=O)',  # Isoleucine
    'K': 'N[C@@H](CCCCN)C(=O)', 'k': 'N[C@H](CCCCN)C(=O)',  # Lysine
    'L': 'N[C@@H](CC(C)C)C(=O)', 'l': 'N[C@H](CC(C)C)C(=O)',  # Leucine
    'M': 'N[C@@H](CCSC)C(=O)', 'm': 'N[C@H](CCSC)C(=O)',  # Methionine
    'N': 'N[C@@H](CC(=O)N)C(=O)', 'n': 'N[C@H](CC(=O)N)C(=O)',  # Asparagine
    'P': 'N1[C@@H](CCC1)C(=O)', 'p': 'N1[C@H](CCC1)C(=O)',  # Proline
    'Q': 'N[C@@H](CCC(=O)N)C(=O)', 'q': 'N[C@H](CCC(=O)N)C(=O)',  # Glutamine
    'R': 'N[C@@H](CCCNC(=N)N)C(=O)', 'r': 'N[C@H](CCCNC(=N)N)C(=O)',  # Arginine
    'S': 'N[C@@H](CO)C(=O)', 's': 'N[C@H](CO)C(=O)',  # Serine
    'T': 'N[C@@H](C(O)C)C(=O)', 't': 'N[C@H](C(O)C)C(=O)',  # Threonine
    'V': 'N[C@@H](C(C)C)C(=O)', 'v': 'N[C@H](C(C)C)C(=O)',  # Valine
    'W': 'N[C@@H](CC1=CNC2=CC=CC=C12)C(=O)', 'w': 'N[C@H](CC1=CNC2=CC=CC=C12)C(=O)',  # Tryptophan
    'Y': 'N[C@@H](CC1=CC=C(O)C=C1)C(=O)', 'y': 'N[C@H](CC1=CC=C(O)C=C1)C(=O)',  # Tyrosine
    'X': '*', '?': '*',  # Wildcard for unknown residues
    'O': 'N[C@@H](CCC(N)C(=O))C(=O)',  # Ornithine
}

# %%
# Updated modification and amino acid SMILES map
modification_smiles_map.update({
    "NII": "NC(C)C(=O)",  # Example placeholder for NII
    "PIC": "N1C=C(C(=O)N1)C",  # Example placeholder for PIC
    "IC": "NC1=NC=NC(=O)1"  # Example placeholder for IC
})

aa_smiles_map.update({
    'Aib': 'N[C@H](C(C)C)C(=O)',  # Alpha-aminoisobutyric acid
    'B': 'N[C@@H](CC(=O)O)C(=O)',  # Ambiguous (Asn/Asp as example)
    'b': 'N[C@@H](CS)C(=O)'  # Could be beta-Amino acid or placeholder
})

# %%
from collections import Counter

# Dictionary to count unrecognized amino acids
unrecognized_amino_acids_count = Counter()
UNRECOGNIZED_SEQUENCES = set()

# Function to handle repeats like R8 or S5
def expand_repeats(sequence):
    import re
    repeat_pattern = re.compile(r'([A-Z][a-z]*)(\d+)')
    expanded = []
    for match in repeat_pattern.finditer(sequence):
        aa, count = match.groups()
        expanded.append(aa * int(count))
    return re.sub(repeat_pattern, '', sequence) + ''.join(expanded)

# Function to convert raw sequence into SMILES
def raw_sequence_to_smiles(sequence):
    smiles_parts = []

    # Expand repeats like R8 or S5
    sequence = expand_repeats(sequence)

    # Handle modifications in the sequence
    for mod, mod_smiles in modification_smiles_map.items():
        if mod in sequence:
            sequence = sequence.replace(mod, "")
            smiles_parts.append(mod_smiles)

    # Handle the core amino acid sequence
    for aa in re.findall(r'[A-Z][a-z]*', sequence):
        if aa in aa_smiles_map:
            smiles_parts.append(aa_smiles_map[aa])
        else:
            print(f"Warning: Unrecognized amino acid or modification '{aa}' in {sequence}")
            unrecognized_amino_acids_count[aa] += 1
            UNRECOGNIZED_SEQUENCES.add(sequence)

    # Join SMILES fragments
    final_smiles = ''.join(smiles_parts)

    # Validate with RDKit
    try:
        mol = Chem.MolFromSmiles(final_smiles)
        return Chem.MolToSmiles(mol) if mol else None
    except Exception:
        return None

# %%
df['smiles_sequence'] = df['sequence'].apply(raw_sequence_to_smiles)
# Out:
# Warning: Unrecognized amino acid or modification 'Acp' in (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK
# Warning: Unrecognized amino acid or modification 'Acp' in (Acp)-RKRRQTSMTDFYHSKRRLIFS
# Warning: Unrecognized amino acid or modification 'Krrrrrrr' in ?A-[KrrrrrrrE]
# Warning: Unrecognized amino acid or modification 'Krrrrrrrr' in ?A-[KrrrrrrrrE]
# Warning: Unrecognized amino acid or modification 'Bpg' in A-C-Bpg-LYLLGKINLKALAALAKKILFFF
# Warning: Unrecognized amino acid or modification 'Bpg' in AGY-C-Bpg-LGKINLKALAALAKKILFFF
# Warning: Unrecognized amino acid or modification 'Ksa' in AGYLLGK[Ksa4qn4]INLKALAALAKKILKK
# Warning: Unrecognized amino acid or modification 'Cya' in GLWWRLWWRLRSWFRLWFRA-Cya
# Warning: Unrecognized amino acid or modification 'Cya' in KETWWETWWTEWSQPKKKRKV-Cya
# Warning: Unrecognized amino acid or modification 'Ct' in XPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in XPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in XPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in XPAANVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in XPAANVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Ct' in eeeeeeeeeXPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in eeeeeeeeeXPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in eeeeeeeeeXPAACtVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Ct' in eeeeeeeeeXPAACtVGrrrrrrrrrXk([125I]IB)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in eeeeeeeeeXPAACtVGrrrrrrrrrXk([125I]IB)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in eeeeeeeeeXPAACtVGrrrrrrrrrXk([125I]IB)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in eeeeeeeeeXPAANVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in eeeeeeeeeXPAANVGrrrrrrrrrXk(FL)-NHH
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in eeeeeeeeeXPAANVGrrrrrrrrrXk([125I]IB)-NHH
# Warning: Unrecognized amino acid or modification 'Xk' in eeeeeeeeeXPAANVGrrrrrrrrrXk([125I]IB)-NHH
# Warning: Unrecognized amino acid or modification 'Ac' in AcHGLASTLTRWAHYNALIRAFC-CONHH
# Warning: Unrecognized amino acid or modification 'Acetyl' in Acetyl-RLWRLLWRLWRRLWRLLR-NHH
# Warning: Unrecognized amino acid or modification 'Ahx' in Ahx-RRRRRRRRR
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KRrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Kr' in B-[KrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Rr' in B-[KrRrRrRrE]
# Warning: Unrecognized amino acid or modification 'Krrrrrrr' in B-[KrrrrrrrE]
# Warning: Unrecognized amino acid or modification 'Krrrrrrrr' in B-[KrrrrrrrrE]
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 10 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 10 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Rr' in BRrXRrXRrX
# Warning: Unrecognized amino acid or modification 'Rr' in BRrXRrXRrX
# Warning: Unrecognized amino acid or modification 'Rr' in BRrXRrXRrX
# Warning: Unrecognized amino acid or modification 'Brr' in BrrXrrXrrX
# Warning: Unrecognized amino acid or modification 'Xrr' in BrrXrrXrrX
# Warning: Unrecognized amino acid or modification 'Xrr' in BrrXrrXrrX
# Warning: Unrecognized amino acid or modification 'Cys' in CF-Cys-BLGTYTQDFNXFHTFPQTAIGVGAP
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ac' in CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# Warning: Unrecognized amino acid or modification 'Ahx' in CGRKKR-Ahx-RQR-Ahx-R-ahx-RPPQ
# Warning: Unrecognized amino acid or modification 'Ahx' in CGRKKR-Ahx-RQR-Ahx-R-ahx-RPPQ
# Warning: Unrecognized amino acid or modification 'Ahx' in CGRKKR-Ahx-RQRRRPPQ
# Warning: Unrecognized amino acid or modification 'Ahx' in CGRKKRRQR-Ahx-RRPPQ
# Warning: Unrecognized amino acid or modification 'Ahx' in CGRKKRRQRR-Ahx-RPPQ
# Warning: Unrecognized amino acid or modification 'Cys' in CKRRMKWKK-Cys
# Warning: Unrecognized amino acid or modification 'Rw' in CRWRwKCCKK
# Warning: Unrecognized amino acid or modification 'Wr' in CRWrWKCCKK
# Warning: Unrecognized amino acid or modification 'Rw' in CRwRWKCCKK
# Warning: Unrecognized amino acid or modification 'Cr' in CrWRWKCCKK
# Warning: Unrecognized amino acid or modification 'Crwrw' in CrwrwKCCKK
# Warning: Unrecognized amino acid or modification 'Cyclo' in Cyclo(FΦRRRRQ)
# Warning: Unrecognized amino acid or modification 'Cys' in Cys-RRRRRRRR-EGR-Lip
# Warning: Unrecognized amino acid or modification 'Lip' in Cys-RRRRRRRR-EGR-Lip
# Warning: Unrecognized amino acid or modification 'Cys' in Cys-RRRRRRRR-RGD-Lip
# Warning: Unrecognized amino acid or modification 'Lip' in Cys-RRRRRRRR-RGD-Lip
# Warning: Unrecognized amino acid or modification 'Cys' in Cys-RRRRRRRR-dGR-Lip
# Warning: Unrecognized amino acid or modification 'Lip' in Cys-RRRRRRRR-dGR-Lip
# Warning: Unrecognized amino acid or modification 'Dabcyl' in Dabcyl-RRRRRRK-Rho-NHH
# Warning: Unrecognized amino acid or modification 'Rho' in Dabcyl-RRRRRRK-Rho-NHH
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:31] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Yp' in FFAARTMIWYpGAWYKRI
# Warning: Unrecognized amino acid or modification 'Grrr' in FFFFFFGGGGGGrrrRR
# Warning: Unrecognized amino acid or modification 'Qq' in FKQqQqQqQqQq
# Warning: Unrecognized amino acid or modification 'Qq' in FKQqQqQqQqQq
# Warning: Unrecognized amino acid or modification 'Qq' in FKQqQqQqQqQq
# Warning: Unrecognized amino acid or modification 'Qq' in FKQqQqQqQqQq
# Warning: Unrecognized amino acid or modification 'Qq' in FKQqQqQqQqQq
# Warning: Unrecognized amino acid or modification 'Me' in FSDMeSSSVPNBBRNCG
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Xr' in FXrFXrFXrFXrFXrFXr
# Warning: Unrecognized amino acid or modification 'Fr' in FrFKFrFK
# Warning: Unrecognized amino acid or modification 'Fr' in FrFKFrFK
# Warning: Unrecognized amino acid or modification 'Abu' in GD(Abu)LPHLKLC
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in GLFEAIEGFIENGWEGMIDGWYGGGGrrrrrrrrrK
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Qrrrrrrrrr' in GPLGIAGQrrrrrrrrr
# Warning: Unrecognized amino acid or modification 'Rho' in H-RRRRRRK-Rho-NHH
# Warning: Unrecognized amino acid or modification 'Hrrrrrrrrr' in HHHHHHrrrrrrrrr
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in -GRKKRRQRRR-NHisHisHisHisHisHisHH
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Hey' in K-Hey-FQWQRNMRKVRGPPVS-Hey-IKR
# Warning: Unrecognized amino acid or modification 'Hey' in K-Hey-FQWQRNMRKVRGPPVS-Hey-IKR
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLU
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLU
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLU
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLU
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLU
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLUGC
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLUGC
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLUGC
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLUGC
# Warning: Unrecognized amino acid or modification 'U' in KLULKLULKULKAULKLUGC
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Kr' in KrKfIcL
# Warning: Unrecognized amino acid or modification 'Kf' in KrKfIcL
# Warning: Unrecognized amino acid or modification 'Ic' in KrKfIcL
# Warning: Unrecognized amino acid or modification 'Kr' in KrKfIcLGRaDPAYQaRFL
# Warning: Unrecognized amino acid or modification 'Kf' in KrKfIcLGRaDPAYQaRFL
# Warning: Unrecognized amino acid or modification 'Ic' in KrKfIcLGRaDPAYQaRFL
# Warning: Unrecognized amino acid or modification 'Ra' in KrKfIcLGRaDPAYQaRFL
# Warning: Unrecognized amino acid or modification 'Qa' in KrKfIcLGRaDPAYQaRFL
# Warning: Unrecognized amino acid or modification 'Kr' in KrKiFcL
# Warning: Unrecognized amino acid or modification 'Ki' in KrKiFcL
# Warning: Unrecognized amino acid or modification 'Fc' in KrKiFcL
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrGgKkRrD
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrD
# Warning: Unrecognized amino acid or modification 'Gg' in KrRrGgKkRrD
# Warning: Unrecognized amino acid or modification 'Kk' in KrRrGgKkRrD
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrD
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrGgKkRrD-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrD-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Gg' in KrRrGgKkRrD-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Kk' in KrRrGgKkRrD-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrD-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrGgKkRrDLTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrDLTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Gg' in KrRrGgKkRrDLTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Kk' in KrRrGgKkRrDLTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrGgKkRrDLTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrRrRrRrRE
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Kr' in KrRrRrRrRrRELTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRELTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRELTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRELTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Rr' in KrRrRrRrRrRELTFKEYWDQLTSAA
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in LAELLAELLAELGGGGrrrrrrrrr
# Warning: Unrecognized amino acid or modification 'Kl' in LKlLKkLlkKLLkLL
# Warning: Unrecognized amino acid or modification 'Kk' in LKlLKkLlkKLLkLL
# Warning: Unrecognized amino acid or modification 'Llk' in LKlLKkLlkKLLkLL
# Warning: Unrecognized amino acid or modification 'Lk' in LKlLKkLlkKLLkLL
# Warning: Unrecognized amino acid or modification 'Ha' in LLIILRRRIRKQAHaHSK
# Warning: Unrecognized amino acid or modification 'Qa' in LLIILRRRIRKQaHAHSK
# Warning: Unrecognized amino acid or modification 'Rho' in M-Rho-GRKKRRQRRR-NHH
# Warning: Unrecognized amino acid or modification 'Ahx' in MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Gr' in MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rh' in MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Gr' in MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rh' in MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Gr' in MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:32] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Me' in Me-RKKRRRESWVHLPPPVHLPPPGGHHHHHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-GSLKTRVLKR-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-KLFNKQEWTN-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-KRWKLFNKQE-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-KTRVLKRWKL-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-LKRWKLFNKQ-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-LKTRVLKRWK-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-RVLKRWKLFN-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-RWKLFNKQEW-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-SLKTRVLKRW-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-TRVLKRWKLF-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-VLKRWKLFNK-NHH
# Warning: Unrecognized amino acid or modification 'Mpa' in Mpa(luc)-WKLFNKQEWT-NHH
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Leu' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Leu' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Leu' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Leu' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Nleu' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Npm' in NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Lys' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nssb' in NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nbtg' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Nspe' in Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Lip' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# Warning: Unrecognized amino acid or modification 'Cou' in PFVYL-Lip-CouCouCouCouCouCou
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Ahx' in RGD-Ahx-RRRRRRRR
# Warning: Unrecognized amino acid or modification 'Pdna' in RKKRRQRRR-OL-Pdna
# Warning: Unrecognized amino acid or modification 'Ps' in RRRRRRRR-H-NPs-siScr
# Warning: Unrecognized amino acid or modification 'Scr' in RRRRRRRR-H-NPs-siScr
# Warning: Unrecognized amino acid or modification 'Lip' in RRRRRRRR-Lip
# Warning: Unrecognized amino acid or modification 'Df' in RRRRRRRR-c(RGDfK)
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Ra' in RaDPAYQaRFLGKrKfIcL
# Warning: Unrecognized amino acid or modification 'Qa' in RaDPAYQaRFLGKrKfIcL
# Warning: Unrecognized amino acid or modification 'Kr' in RaDPAYQaRFLGKrKfIcL
# Warning: Unrecognized amino acid or modification 'Kf' in RaDPAYQaRFLGKrKfIcL
# Warning: Unrecognized amino acid or modification 'Ic' in RaDPAYQaRFLGKrKfIcL
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Et' in TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# Warning: Unrecognized amino acid or modification 'Tf' in Tf-PFVYLI
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# [17:13:33] Explicit valence for atom # 5 C, 5, is greater than permitted
# Warning: Unrecognized amino acid or modification 'Al' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Av' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Vv' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Wl' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Wl' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Wl' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Wb' in VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# Warning: Unrecognized amino acid or modification 'Ahx' in YKQCHKKGG-Ahx-KKGSG
# Warning: Unrecognized amino acid or modification 'Z' in Z-LRGG-AMC
# Warning: Unrecognized amino acid or modification 'Bpg' in a-C-Bpg-lyllgkinlkalaalakkilFFF
# Warning: Unrecognized amino acid or modification 'Bpg' in agy-C-Bpg-lgkinlkalaalakkilFFF
# Warning: Unrecognized amino acid or modification 'Rk' in kRkFiCl
# Warning: Unrecognized amino acid or modification 'Fi' in kRkFiCl
# Warning: Unrecognized amino acid or modification 'Cl' in kRkFiCl
# Warning: Unrecognized amino acid or modification 'Rk' in kRkIfCl
# Warning: Unrecognized amino acid or modification 'If' in kRkIfCl
# Warning: Unrecognized amino acid or modification 'Cl' in kRkIfCl
# Warning: Unrecognized amino acid or modification 'Ga' in kkwkmrrGaGrrrrrrrrr
# Warning: Unrecognized amino acid or modification 'Grrrrrrrrr' in kkwkmrrGaGrrrrrrrrr
# Warning: Unrecognized amino acid or modification 'Fr' in rFTFHFrFEFTFHFE
# Warning: Unrecognized amino acid or modification 'Lr' in rHHLrHLrrHLrHLLrHLrHHL
# Warning: Unrecognized amino acid or modification 'Lrr' in rHHLrHLrrHLrHLLrHLrHHL
# Warning: Unrecognized amino acid or modification 'Lr' in rHHLrHLrrHLrHLLrHLrHHL
# Warning: Unrecognized amino acid or modification 'Lr' in rHHLrHLrrHLrHLLrHLrHHL
# Warning: Unrecognized amino acid or modification 'Lr' in rHHLrHLrrHLrHLLrHLrHHL
# Warning: Unrecognized amino acid or modification 'Hr' in rHNHrFNFrFFFNFrFNTrTN
# Warning: Unrecognized amino acid or modification 'Fr' in rHNHrFNFrFFFNFrFNTrTN
# Warning: Unrecognized amino acid or modification 'Fr' in rHNHrFNFrFFFNFrFNTrTN
# Warning: Unrecognized amino acid or modification 'Tr' in rHNHrFNFrFFFNFrFNTrTN
# Warning: Unrecognized amino acid or modification 'Hr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Hrr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Hr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Hrr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Hr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Hr' in rHrHrrHrHrrHrHr
# Warning: Unrecognized amino acid or modification 'Lr' in rLLrLLLrLWrrLLrLLr
# Warning: Unrecognized amino acid or modification 'Lr' in rLLrLLLrLWrrLLrLLr
# Warning: Unrecognized amino acid or modification 'Wrr' in rLLrLLLrLWrrLLrLLr
# Warning: Unrecognized amino acid or modification 'Lr' in rLLrLLLrLWrrLLrLLr
# Warning: Unrecognized amino acid or modification 'Lr' in rLLrLLLrLWrrLLrLLr
# Warning: Unrecognized amino acid or modification 'Rr' in rRRRRRRRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrGrKkRr
# Warning: Unrecognized amino acid or modification 'Gr' in rRrGrKkRr
# Warning: Unrecognized amino acid or modification 'Kk' in rRrGrKkRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrGrKkRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRRRRR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRRR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrR
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrRr
# Warning: Unrecognized amino acid or modification 'Rr' in rRrRrRrRr
# Warning: Unrecognized amino acid or modification 'Xrr' in rXrrXrrXrrXr
# Warning: Unrecognized amino acid or modification 'Xrr' in rXrrXrrXrrXr
# Warning: Unrecognized amino acid or modification 'Xrr' in rXrrXrrXrrXr
# Warning: Unrecognized amino acid or modification 'Xr' in rXrrXrrXrrXr
# Warning: Unrecognized amino acid or modification 'Rr' in rrrRrRrR
# Warning: Unrecognized amino acid or modification 'Rr' in rrrRrRrR
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'His' in stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# Warning: Unrecognized amino acid or modification 'Gkk' in ykqchkkGGkkGsG
# Warning: Unrecognized amino acid or modification 'Gs' in ykqchkkGGkkGsG
# Warning: Unrecognized amino acid or modification 'Steary' in ε-(Steary-AGYLLG)KINLKALAALAKKIL
# [17:13:34] Explicit valence for atom # 5 C, 5, is greater than permitted

# %%
unrecognized_amino_acids_count
# Out:
# Counter({'O': 83,
#          'Rr': 52,
#          'Lys': 39,
#          'Ac': 34,
#          'Nspe': 34,
#          'Nbtg': 20,
#          'Xr': 19,
#          'Et': 18,
#          'His': 12,
#          'Mpa': 12,
#          'Cou': 12,
#          'Kr': 11,
#          'U': 10,
#          'Grrrrrrrrr': 9,
#          'Ahx': 9,
#          'Npm': 8,
#          'Nssb': 8,
#          'Lr': 8,
#          'Xk': 6,
#          'Xrr': 5,
#          'Cys': 5,
#          'Lip': 5,
#          'Qq': 5,
#          'Fr': 5,
#          'Kk': 5,
#          'Hr': 5,
#          'Bpg': 4,
#          'Gr': 4,
#          'Leu': 4,
#          'Ct': 3,
#          'Rho': 3,
#          'Kf': 3,
#          'Ic': 3,
#          'Qa': 3,
#          'Gg': 3,
#          'Wl': 3,
#          'Acp': 2,
#          'Krrrrrrr': 2,
#          'Krrrrrrrr': 2,
#          'Cya': 2,
#          'Rw': 2,
#          'Me': 2,
#          'Hey': 2,
#          'Ra': 2,
#          'Rh': 2,
#          'Rk': 2,
#          'Cl': 2,
#          'Hrr': 2,
#          'Ksa': 1,
#          'Acetyl': 1,
#          'Brr': 1,
#          'Wr': 1,
#          'Cr': 1,
#          'Crwrw': 1,
#          'Cyclo': 1,
#          'Dabcyl': 1,
#          'Yp': 1,
#          'Grrr': 1,
#          'Abu': 1,
#          'Qrrrrrrrrr': 1,
#          'Hrrrrrrrrr': 1,
#          'Ki': 1,
#          'Fc': 1,
#          'Kl': 1,
#          'Llk': 1,
#          'Lk': 1,
#          'Ha': 1,
#          'Nleu': 1,
#          'Pdna': 1,
#          'Ps': 1,
#          'Scr': 1,
#          'Df': 1,
#          'Tf': 1,
#          'Al': 1,
#          'Av': 1,
#          'Vv': 1,
#          'Wb': 1,
#          'Z': 1,
#          'Fi': 1,
#          'If': 1,
#          'Ga': 1,
#          'Lrr': 1,
#          'Tr': 1,
#          'Wrr': 1,
#          'Gkk': 1,
#          'Gs': 1,
#          'Steary': 1})

# %%
for el in UNRECOGNIZED_SEQUENCES:
    print(el)
# Out:
# FKQqQqQqQqQq
# kkwkmrrGaGrrrrrrrrr
# Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe-Nbtg-Nbtg-Nspe
# rXrrXrrXrrXr
# -GRKKRRQRRR-NHisHisHisHisHisHisHH
# rRrGrKkRr
# (Acp)-RKRRQTSMTDFYHSKRRLIFS
# CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcAcHHAcAcAcAcAcAcHHAcAcAcAcAcAcHHHH
# B-[KRrRrRrRrE]
# eeeeeeeeeXPAANVGrrrrrrrrrXk([125I]IB)-NHH
# FXrFXrFXrFXr
# Mpa(luc)-LKTRVLKRWK-NHH
# Mpa(luc)-KLFNKQEWTN-NHH
# rRrRrRrRr
# PFVYL-Lip-CouCouCouCouCouCou
# CGRKKRRQRR-Ahx-RPPQ
# FXrFXrFXr
# AGYLLGK[Ksa4qn4]INLKALAALAKKILKK
# FXrFXrFXrFXrFXr
# Me-RKKRRRESWVHLPPPVHLPPPGGHHHHHH
# stearly--HHHHHHHHHHHHHHHH–NHisHisHisHisHisHisHH
# KrRrRrRrRrRELTFKEYWDQLTSAA
# rFTFHFrFEFTFHFE
# CGRKKRRQR-Ahx-RRPPQ
# CRWRwKCCKK
# NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
# FFFFFFGGGGGGrrrRR
# ?A-[KrrrrrrrrE]
# BrrXrrXrrX
# GPLGIAGQrrrrrrrrr
# KrRrGgKkRrDLTFKEYWDQLTSAA
# rrrRrRrR
# RRRRRRRR-H-NPs-siScr
# CF-GRR-cN-RR-cN-RR-cN-NAcAcAcAcAcHHAcAcAcAcAcHHAcAcAcAcAcHHHH
# Cys-RRRRRRRR-dGR-Lip
# Acetyl-RLWRLLWRLWRRLWRLLR-NHH
# RaDPAYQaRFLGKrKfIcL
# Tf-PFVYLI
# LAELLAELLAELGGGGrrrrrrrrr
# eeeeeeeeeXPAANVGrrrrrrrrrXk(FL)-NHH
# Mpa(luc)-RWKLFNKQEW-NHH
# Z-LRGG-AMC
# AGY-C-Bpg-LGKINLKALAALAKKILFFF
# ykqchkkGGkkGsG
# TMR-G(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)(AEt)-NHH
# FXrFXrFXrFXrFXrFXr
# kRkFiCl
# kRkIfCl
# XPAACtVGrrrrrrrrrXk(FL)-NHH
# rRrRrRrR
# PFVYL-CouCouCouCouCouCou
# KrRrGgKkRrD-LTFKEYWDQLTSAA
# Cyclo(FΦRRRRQ)
# eeeeeeeeeXPAACtVGrrrrrrrrrXk([125I]IB)-NHH
# rLLrLLLrLWrrLLrLLr
# YKQCHKKGG-Ahx-KKGSG
# NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe-NLys-NLys-Nspe
# Cys-RRRRRRRR-RGD-Lip
# B-[KrrrrrrrrE]
# MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
# B-[KRrRrRrE]
# K-Hey-FQWQRNMRKVRGPPVS-Hey-IKR
# rHrHrrHrHrrHrHr
# VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# CGRKKR-Ahx-RQRRRPPQ
# CKRRMKWKK-Cys
# Mpa(luc)-LKRWKLFNKQ-NHH
# Ahx-RRRRRRRRR
# LLIILRRRIRKQaHAHSK
# Mpa(luc)-KRWKLFNKQE-NHH
# (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK
# MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
# A-C-Bpg-LYLLGKINLKALAALAKKILFFF
# eeeeeeeeeXPAACtVGrrrrrrrrrXk(FL)-NHH
# M-Rho-GRKKRRQRRR-NHH
# HHHHHHrrrrrrrrr
# TMR-G(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)(GEt)-NHH
# B-[KrrrrrrrE]
# CGRKKR-Ahx-RQR-Ahx-R-ahx-RPPQ
# FFAARTMIWYpGAWYKRI
# GD(Abu)LPHLKLC
# NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb-NLys-Nssb-Nssb
# ?A-[KrrrrrrrE]
# Cys-RRRRRRRR-EGR-Lip
# Mpa(luc)-VLKRWKLFNK-NHH
# KrRrRrRrRrRE
# KLULKLULKULKAULKLUGC
# rRRRRRRRr
# MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
# KrKfIcLGRaDPAYQaRFL
# CRwRWKCCKK
# CrwrwKCCKK
# Dabcyl-RRRRRRK-Rho-NHH
# a-C-Bpg-lyllgkinlkalaalakkilFFF
# H-RRRRRRK-Rho-NHH
# Mpa(luc)-SLKTRVLKRW-NHH
# rRrRrRRR
# Mpa(luc)-KTRVLKRWKL-NHH
# rRrRRRRR
# RKKRRQRRR-OL-Pdna
# Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe-Nbtg-Nspe-Nspe
# NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# Mpa(luc)-RVLKRWKLFN-NHH
# agy-C-Bpg-lgkinlkalaalakkilFFF
# B-[KrRrRrRrE]
# FSDMeSSSVPNBBRNCG
# KrRrGgKkRrD
# KrRrRrRrRrRE-LTFKEYWDQLTSAA
# Mpa(luc)-GSLKTRVLKR-NHH
# KLULKLULKULKAULKLU
# ε-(Steary-AGYLLG)KINLKALAALAKKIL
# CF-Cys-BLGTYTQDFNXFHTFPQTAIGVGAP
# GLFEAIEGFIENGWEGMIDGWYGGGGrrrrrrrrrK
# KrKiFcL
# CRWrWKCCKK
# KrKfIcL
# LLIILRRRIRKQAHaHSK
# rHNHrFNFrFFFNFrFNTrTN
# NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-Nspe-Nspe-Nspe-Nspe
# rHHLrHLrrHLrHLLrHLrHHL
# Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg-Nbtg
# RGD-Ahx-RRRRRRRR
# LKlLKkLlkKLLkLL
# KETWWETWWTEWSQPKKKRKV-Cya
# GLWWRLWWRLRSWFRLWFRA-Cya
# NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm-NLys-Npm-Npm
# FrFKFrFK
# RRRRRRRR-Lip
# NLys-Nspe-Nspe-NLys-Nspe-Nspe-NLys-Nspe-Nspe
# XPAANVGrrrrrrrrrXk(FL)-NHH
# BRrXRrXRrX
# Mpa(luc)-TRVLKRWKLF-NHH
# Mpa(luc)-WKLFNKQEWT-NHH
# AcHGLASTLTRWAHYNALIRAFC-CONHH
# RRRRRRRR-c(RGDfK)
# CrWRWKCCKK

# %%
# Update modification and amino acid SMILES map to handle the unrecognized amino acids
modification_smiles_map.update({
    "Nspe": "N[C@H](C(C)O)C(=O)",  # Placeholder for N-spe (needs actual structure)
    "Nbtg": "N[C@H](C(C)(C)C)C(=O)",  # Placeholder for N-btg (needs actual structure)
    "Ac": "CC(=O)",  # Acetyl group (already in the original map, handling here for completeness)
    "Et": "CC",  # Ethyl group (modification, placeholder)
    "Npm": "N1[C@H](C(C)C)C(=O)",  # Placeholder for Npm (needs actual structure)
    "Nssb": "N1[C@H](C(C)CC)C(=O)",  # Placeholder for Nssb (needs actual structure)
    "Mpa": "NC(=O)C(C)C(C)C(=O)",  # Placeholder for Mpa (needs actual structure)
    "Cou": "C1=CC2=C(C=C1)C(=O)O2",  # Placeholder for Cou (needs actual structure)
    "Xr": "N[C@H](C(C)C)C(=O)",  # Placeholder for Xr (needs actual structure)
    "His": "N[C@@H](CC1=CNC=N1)C(=O)",  # Histidine (already handled in the original map, handling here for completeness)
})

aa_smiles_map.update({
    'Rr': 'N[C@@H](CC(C)C)C(=O)',  # Placeholder for Rr (represents an amino acid sequence with R and R-like groups)
    'Lys': 'N[C@H](CCCCN)C(=O)',  # Lysine (already in original map)
    'Grrrrrrrrr': 'N[C@@H](C(C)CCCCCCCCCC)C(=O)',  # Placeholder for Grrrrrrrrr, assume a modified version
    'Ahx': 'N[C@H](CC(C)CC)C(=O)',  # Placeholder for Ahx (needs actual structure)
    'Kr': 'N[C@H](CC(C)CN)C(=O)',  # Placeholder for Kr (needs actual structure)
    'Lr': 'N[C@H](CC(C)C(C)C)C(=O)',  # Placeholder for Lr (needs actual structure)
    'U': 'NC1=NC2=C(C=C1)C(=O)N2',  # Placeholder for U (assumed modified structure)
})

# %%
# Dictionary to count unrecognized amino acids
unrecognized_amino_acids_count = Counter()
UNRECOGNIZED_SEQUENCES = set()

# Function to handle repeats like R8 or S5
def expand_repeats(sequence):
    repeat_pattern = re.compile(r'([A-Z][a-z]*)(\d+)')
    expanded = []
    for match in repeat_pattern.finditer(sequence):
        aa, count = match.groups()
        expanded.append(aa * int(count))
    return re.sub(repeat_pattern, '', sequence) + ''.join(expanded)

# Function to convert raw sequence into SMILES
def raw_sequence_to_smiles(sequence):
    smiles_parts = []

    # Expand repeats like R8 or S5
    sequence = expand_repeats(sequence)

    # Handle modifications in the sequence
    for mod, mod_smiles in modification_smiles_map.items():
        if mod in sequence:
            sequence = sequence.replace(mod, "")
            smiles_parts.append(mod_smiles)

    # Handle the core amino acid sequence
    for aa in re.findall(r'[A-Z][a-z]*', sequence):
        if aa in aa_smiles_map:
            smiles_parts.append(aa_smiles_map[aa])
        else:
            unrecognized_amino_acids_count[aa] += 1
            UNRECOGNIZED_SEQUENCES.add(sequence)

    # Join SMILES fragments
    final_smiles = ''.join(smiles_parts)

    # Validate with RDKit
    try:
        mol = Chem.MolFromSmiles(final_smiles)
        return Chem.MolToSmiles(mol) if mol else None
    except Exception:
        return None

# %% [markdown]
# Final function

# %%
def sequence_to_smiles(row):
    try:
        mol = Chem.MolFromSequence(row['sequence'])
        if not mol:
            return raw_sequence_to_smiles(row['sequence'])
        if mol:
            return Chem.MolToSmiles(mol) if mol else None
    except Exception as e:
        return raw_sequence_to_smiles(row['sequence'])

# %%
df['smiles_sequence'] = df.apply(sequence_to_smiles, axis=1)
# Out:
# [17:25:55] Explicit valence for atom # 10 C, 5, is greater than permitted
# [17:25:55] Explicit valence for atom # 10 C, 5, is greater than permitted
# [17:25:56] SMILES Parse Error: unclosed ring for input: 'N1[C@H](C(C)CC)C(=O)N[C@@H](CC(=O)N)C(=O)N[C@H](CCCCN)C(=O)N[C@@H](CC(=O)N)C(=O)N[C@H](CCCCN)C(=O)N[C@@H](CC(=O)N)C(=O)N[C@H](CCCCN)C(=O)N[C@@H](CC(=O)N)C(=O)N[C@H](CCCCN)C(=O)'
# [17:25:56] Explicit valence for atom # 8 O, 3, is greater than permitted
# [17:25:56] Explicit valence for atom # 8 O, 3, is greater than permitted

# %%
df.head()
# Out:
#                                            sequence extra_name cpp_category  \
# 0                   (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK        NaN          NaN
# 3                       (Acp)-RKRRQTSMTDFYHSKRRLIFS        NaN          NaN
# 7  (biotin)-lclrpvgggweaklakalakalakhlakalakalkacea        NaN          NaN
# 8           (biotin)-lclrpvggrsqsrsryyrqrqrsrrrrrrs        NaN          NaN
# 9                                   ?A-RR-[KRRRRRE]        NaN          NaN
#
#    seq_length  is_cpp cpp_type origin  mol_weight           sequence_category  \
# 0          31    True      NaN    NaN         NaN  Peptide with Substitutions
# 3          27    True      NaN    NaN         NaN  Peptide with Substitutions
# 7          48    True      NaN    NaN         NaN                Biotinylated
# 8          39    True      NaN    NaN         NaN                Biotinylated
# 9          15    True      NaN    NaN         NaN                     Unknown
#
#             standard_sequence  ...  po3_pos  biotinylated  \
# 0  AKKKKKRFSFKKSFKLSGFSFKKNKK  ...    False         False
# 3      ARKRRQTSMTDFYHSKRRLIFS  ...    False         False
# 7                         NaN  ...    False          True
# 8                         NaN  ...    False          True
# 9                  ARRKRRRRRE  ...    False         False
#
#    acylated_n_terminal  cyclic  amidated  stearyl_uptake  \
# 0                False   False     False           False
# 3                False   False     False           False
# 7                False   False     False           False
# 8                False   False     False           False
# 9                False   False     False           False
#
#    hexahistidine_tagged         modifications  \
# 0                 False  [('C', 2), ('P', 3)]
# 3                 False  [('C', 2), ('P', 3)]
# 7                 False                    []
# 8                 False                    []
# 9                 False                    []
#
#                                      smiles_sequence is_valid_smiles
# 0  CC(=O)N[C@@H](CCCCN)C(=O)N[C@@H](CCCCN)C(=O)N[...            True
# 3  CCC(C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCC...            True
# 7                             NC(=O)CCC(=O)NC1CCCCC1            True
# 8                             NC(=O)CCC(=O)NC1CCCCC1            True
# 9  C[C@H](N)C(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](...            True
#
# [5 rows x 21 columns]

# %%
# Check if SMILES are not NaN
valid_smiles = df['smiles_sequence'].notna()

# Calculate the percentage of valid SMILES
valid_percentage = valid_smiles.mean() * 100
invalid_percentage = 100 - valid_percentage

# Print the percentages
print(f'Percentage of Valid SMILES: {valid_percentage:.2f}%')
print(f'Percentage of Invalid SMILES: {invalid_percentage:.2f}%')
# Out:
# Percentage of Valid SMILES: 99.84%
# Percentage of Invalid SMILES: 0.16%

# %%
from rdkit import Chem

def is_valid_smiles(smiles):
    if not smiles:
        return False
    try:
        mol = Chem.MolFromSmiles(smiles)
        return mol is not None
    except:
        return False

# Apply the validation function to the 'smiles_sequence' column
df['is_valid_smiles'] = df['smiles_sequence'].apply(lambda x: is_valid_smiles(x) if pd.notna(x) else False)

# Calculate the percentage of valid SMILES
valid_percentage = df['is_valid_smiles'].mean() * 100

# Print the percentage of valid SMILES
print(f'Percentage of Valid SMILES: {valid_percentage:.2f}%')

# Check if all SMILES sequences are valid
if valid_percentage == 100:
    print("ALL SMILES ARE VALID!")

# Print the DataFrame with the new column
df.head()
# Out:
# Percentage of Valid SMILES: 99.84%
#                                            sequence extra_name cpp_category  \
# 0                   (Acp)-KKKKKRFSFKKSFKLSGFSFKKNKK        NaN          NaN
# 3                       (Acp)-RKRRQTSMTDFYHSKRRLIFS        NaN          NaN
# 7  (biotin)-lclrpvgggweaklakalakalakhlakalakalkacea        NaN          NaN
# 8           (biotin)-lclrpvggrsqsrsryyrqrqrsrrrrrrs        NaN          NaN
# 9                                   ?A-RR-[KRRRRRE]        NaN          NaN
#
#    seq_length  is_cpp cpp_type origin  mol_weight           sequence_category  \
# 0          31    True      NaN    NaN         NaN  Peptide with Substitutions
# 3          27    True      NaN    NaN         NaN  Peptide with Substitutions
# 7          48    True      NaN    NaN         NaN                Biotinylated
# 8          39    True      NaN    NaN         NaN                Biotinylated
# 9          15    True      NaN    NaN         NaN                     Unknown
#
#             standard_sequence  ...  po3_pos  biotinylated  \
# 0  AKKKKKRFSFKKSFKLSGFSFKKNKK  ...    False         False
# 3      ARKRRQTSMTDFYHSKRRLIFS  ...    False         False
# 7                         NaN  ...    False          True
# 8                         NaN  ...    False          True
# 9                  ARRKRRRRRE  ...    False         False
#
#    acylated_n_terminal  cyclic  amidated  stearyl_uptake  \
# 0                False   False     False           False
# 3                False   False     False           False
# 7                False   False     False           False
# 8                False   False     False           False
# 9                False   False     False           False
#
#    hexahistidine_tagged         modifications  \
# 0                 False  [('C', 2), ('P', 3)]
# 3                 False  [('C', 2), ('P', 3)]
# 7                 False                    []
# 8                 False                    []
# 9                 False                    []
#
#                                      smiles_sequence is_valid_smiles
# 0  CC(=O)N[C@@H](CCCCN)C(=O)N[C@@H](CCCCN)C(=O)N[...            True
# 3  CCC(C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCC...            True
# 7                             NC(=O)CCC(=O)NC1CCCCC1            True
# 8                             NC(=O)CCC(=O)NC1CCCCC1            True
# 9  C[C@H](N)C(=O)N[C@@H](CCCNC(=N)N)C(=O)N[C@@H](...            True
#
# [5 rows x 21 columns]

# %%
BAD_SEQUENCES = """
MGVADLIKKFESISKEEGGGGK(RhB)GGrRrRrRRR
A-C-Bpg-LYLLGKINLKALAALAKKILFFF
eeeeeeeeeXPAACtVGrrrrrrrrrXk(FL)-NHH
H-RRRRRRK-Rho-NHH
eeeeeeeeeXPAANVGrrrrrrrrrXk(FL)-NHH
M-Rho-GRKKRRQRRR-NHH
Z-LRGG-AMC
B-[KrrrrrrrE]
RKKRRQRRR-OL-Pdna
AGY-C-Bpg-LGKINLKALAALAKKILFFF
PFVYL-Lip-
agy-C-Bpg-lgkinlkalaalakkilFFF
GD(Abu)LPHLKLC
FSDMeSSSVPNBBRNCG
BrrrrX
eeeeeeeeeXPAANVGrrrrrrrrrXk([125I]IB)-NHH
# ?A-[KrrrrrrrE]
ε-(Steary-AGYLLG)KINLKALAALAKKIL
XPAACtVGrrrrrrrrrXk(FL)-NHH
CF-Cys-BLGTYTQDFNXFHTFPQTAIGVGAP
AGYLLGK[Ksa4qn4]INLKALAALAKKILKK
Cyclo(FΦRRRRQ)
eeeeeeeeeXPAACtVGrrrrrrrrrXk([125I]IB)-NHH
MGVADLIKKFESISKEEGGGGK(Ahx-FITC)-GGrRrRrRRR
B-[KrrrrrrrrE]
MGVADLIKKFESISKEEGGGGK(PA-RhB)GGrRrRrRRR
NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLys-NLeu-NLeu-NLeu-NLeu-Nleu
XPAANVGrrrrrrrrrXk(FL)-NHH
VGAlAvVvWlWlWlWbA-GSG-PKKKRKVC
# ?A-[KrrrrrrrrE]
RRRRRRRR-c(RGDfK)
Dabcyl-RRRRRRK-Rho-NHH
a-C-Bpg-lyllgkinlkalaalakkilFFF
"""

# %%
df.to_csv('with_smiles.csv', index=False)

# %% [markdown]
# # SMILES based embeddings

# %%
from rdkit.Chem import AllChem

counter = 0

def get_morgan_fingerprint(smiles, radius=2, nBits=1024):
    """Generate a Morgan fingerprint from a SMILES string."""
    try:
        molecule = Chem.MolFromSmiles(smiles)
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(molecule, radius, nBits=nBits)
        return np.array(fingerprint)
    except Exception:
        global counter
        counter += 1
        return np.zeros(nBits)  # Return a zero array of the desired shape if the SMILES is invalid

# Generate fingerprints for all SMILES
fingerprints = []

for smiles in df['smiles_sequence']:
    fingerprint = get_morgan_fingerprint(smiles)
    fingerprints.append(fingerprint)
# Out:
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:22] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:23] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# [21:11:24] DEPRECATION WARNING: please use MorganGenerator
# ...
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:27] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator
# [21:11:28] DEPRECATION WARNING: please use MorganGenerator

# %%
# Convert list of fingerprints to a NumPy array
fingerprints_array = np.array(fingerprints)

print(fingerprints_array.shape)  # Print the shape of the resulting array
print('Empty num:', counter)

# Save the fingerprints to a .npy file
np.save('morgan_fingerprints.npy', fingerprints_array)
# Out:
# (3103, 1024)
# Empty num: 5
